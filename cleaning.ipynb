# %%
import pandas as pd

# %%
import numpy as np

# %%
patients=pd.read_csv("patients.csv")

# %%
treatment=pd.read_csv("treatments.csv")

# %%
treatment_cut=pd.read_csv("treatments_cut.csv")

# %%
adverse=pd.read_csv("adverse_reactions.csv")

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
"""1.change assigned sex to category datatype
2.birthdate to date datatype
3.city,address,zip_code,country,contact have null values.
zip code to int
"""
# Out:
# '1.change assigned sex to category datatype\n2.birthdate to date datatype\n3.city,address,zip_code,country,contact have null values.\nzip code to int\n'

# %%
##to see columns having null values
patients.isnull().any()
# Out:
# patient_id      False
# assigned_sex    False
# given_name      False
# surname         False
# address          True
# city             True
# state            True
# zip_code         True
# country          True
# contact          True
# birthdate       False
# weight          False
# height          False
# bmi             False
# dtype: bool

# %%
patients['assigned_sex']=patients['assigned_sex'].astype("category")

# %%
type(patients['assigned_sex'].values)
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    category
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: category(1), float64(3), int64(2), object(8)
# memory usage: 51.8+ KB

# %%
patients["zip_code"]=patients["zip_code"].astype("int")
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9816\1834561023.py in <module>
# ----> 1 patients["zip_code"]=patients["zip_code"].astype("int")
#
# C:\code\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\code\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# ...

# %%
##Nan is a float value so cant change

# %%
patients["zip_code"]=patients["zip_code"].astype("Int64")

# %%
type(patients["zip_code"].values)
# Out:
# pandas.core.arrays.integer.IntegerArray

# %%
patients["birthdate"]=patients["birthdate"].apply(pd.to_datetime)

# %%
type(patients["birthdate"].values)
# Out:
# numpy.ndarray

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    category
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    Int64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    datetime64[ns]
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: Int64(1), category(1), datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 52.3+ KB

# %%
patients["birthdate"]
# Out:
# 0     1976-07-10
# 1     1967-04-03
# 2     1980-02-19
# 3     1951-07-26
# 4     1928-02-18
#          ...
# 498   1959-04-10
# 499   1948-03-26
# 500   1971-01-13
# 501   1952-02-13
# 502   1954-05-03
# Name: birthdate, Length: 503, dtype: datetime64[ns]

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California     92390
# 1    2370 University Hill Road          Armstrong    Illinois     61812
# 2        1493 Poling Farm Road               York    Nebraska     68467
# ...

# %%
patients.duplicated() ###checking if two rows are duplicated
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 498    False
# 499    False
# 500    False
# 501    False
# 502    False
# Length: 503, dtype: bool

# %%
patients["address"].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 498    False
# 499    False
# 500    False
# 501    False
# 502     True
# Name: address, Length: 503, dtype: bool

# %%
patients[patients["address"].duplicated()]
# Out:
#      patient_id assigned_sex given_name     surname             address  \
# 29           30         male       Jake    Jakobsen   648 Old Dear Lane
# 219         220         male         Mỹ       Quynh                 NaN
# 229         230         male       John         Doe     123 Main Street
# 230         231       female  Elisabeth     Knudsen                 NaN
# 234         235       female    Martina   Tománková                 NaN
# 237         238         male       John         Doe     123 Main Street
# 242         243         male       John     O'Brian                 NaN
# 244         245         male       John         Doe     123 Main Street
# 249         250         male   Benjamin      Mehler                 NaN
# 251         252         male       John         Doe     123 Main Street
# 257         258         male        Jin        Kung                 NaN
# 264         265       female   Wafiyyah      Asfour                 NaN
# ...

# %%
##patient john doe is like aplace holder we need to drop it
patients[(patients["given_name"]=="John") & (patients["surname"]=="Doe")]
# Out:
#      patient_id assigned_sex given_name surname          address      city  \
# 215         216         male       John     Doe  123 Main Street  New York
# 229         230         male       John     Doe  123 Main Street  New York
# 237         238         male       John     Doe  123 Main Street  New York
# 244         245         male       John     Doe  123 Main Street  New York
# 251         252         male       John     Doe  123 Main Street  New York
# 277         278         male       John     Doe  123 Main Street  New York
#
#     state  zip_code        country                      contact  birthdate  \
# 215    NY     12345  United States  johndoe@email.com1234567890 1975-01-01
# 229    NY     12345  United States  johndoe@email.com1234567890 1975-01-01
# 237    NY     12345  United States  johndoe@email.com1234567890 1975-01-01
# 244    NY     12345  United States  johndoe@email.com1234567890 1975-01-01
# ...

# %%
duplicates=patients[(patients["given_name"]=="John") & (patients["surname"]=="Doe")].index

# %%
duplicates
# Out:
# Int64Index([215, 229, 237, 244, 251, 277], dtype='int64')

# %%
patients.drop(duplicates,inplace=True)

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California     92390
# 1    2370 University Hill Road          Armstrong    Illinois     61812
# 2        1493 Poling Farm Road               York    Nebraska     68467
# ...

# %%
patients[patients['address'].duplicated()]
# Out:
#      patient_id assigned_sex given_name     surname             address  \
# 29           30         male       Jake    Jakobsen   648 Old Dear Lane
# 219         220         male         Mỹ       Quynh                 NaN
# 230         231       female  Elisabeth     Knudsen                 NaN
# 234         235       female    Martina   Tománková                 NaN
# 242         243         male       John     O'Brian                 NaN
# 249         250         male   Benjamin      Mehler                 NaN
# 257         258         male        Jin        Kung                 NaN
# 264         265       female   Wafiyyah      Asfour                 NaN
# 269         270       female     Flavia  Fiorentino                 NaN
# 278         279       female   Generosa       Cabán                 NaN
# 282         283       female      Sandy      Taylor  2476 Fulton Street
# 286         287         male      Lewis        Webb                 NaN
# ...

# %%
patients=patients.reset_index(drop=True)

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 492         499         male    Mustafa    Lindström
# 493         500         male      Ruman      Bisliev
# 494         501       female      Jinke    de Keizer
# 495         502       female    Chidalu  Onyekaozulu
# 496         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California     92390
# 1    2370 University Hill Road          Armstrong    Illinois     61812
# 2        1493 Poling Farm Road               York    Nebraska     68467
# ...

# %%
patients["state"].unique()
# Out:
# array(['California', 'Illinois', 'Nebraska', 'NJ', 'AL', 'Florida', 'NV',
#        'CA', 'MO', 'New York', 'MI', 'TN', 'VA', 'OK', 'GA', 'MT', 'MA',
#        'NY', 'NM', 'IL', 'LA', 'PA', 'CO', 'ME', 'WI', 'SD', 'MN', 'FL',
#        'WY', 'OH', 'IA', 'NC', 'IN', 'CT', 'KY', 'DE', 'MD', 'AZ', 'TX',
#        'NE', 'AK', 'ND', 'KS', 'MS', 'WA', 'SC', 'WV', 'RI', 'NH', 'OR',
#        nan, 'VT', 'ID', 'DC', 'AR'], dtype=object)

# %%
states={"Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI"}

# %%
states={states[k]:k for k in states}

# %%
states
# Out:
# {'AL': 'Alabama',
#  'AK': 'Alaska',
#  'AZ': 'Arizona',
#  'AR': 'Arkansas',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DE': 'Delaware',
#  'FL': 'Florida',
#  'GA': 'Georgia',
#  'HI': 'Hawaii',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'IA': 'Iowa',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'ME': 'Maine',
#  'MD': 'Maryland',
#  'MA': 'Massachusetts',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MS': 'Mississippi',
#  'MO': 'Missouri',
#  'MT': 'Montana',
#  'NE': 'Nebraska',
#  'NV': 'Nevada',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NM': 'New Mexico',
#  'NY': 'New York',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'OR': 'Oregon',
#  'PA': 'Pennsylvania',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UT': 'Utah',
#  'VT': 'Vermont',
#  'VA': 'Virginia',
# ...

# %%
patients["state"]=patients["state"].replace(states)

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 492         499         male    Mustafa    Lindström
# 493         500         male      Ruman      Bisliev
# 494         501       female      Jinke    de Keizer
# 495         502       female    Chidalu  Onyekaozulu
# 496         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California     92390
# 1    2370 University Hill Road          Armstrong    Illinois     61812
# 2        1493 Poling Farm Road               York    Nebraska     68467
# ...

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  497.000000    485.000000  497.000000  497.000000  497.000000
# mean   252.106640  49538.622680  173.355734   66.569416   27.521127
# std    146.205675  30173.417289   34.113533    4.398005    5.297277
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    125.000000  23601.000000  148.700000   63.000000   23.200000
# 50%    254.000000  48221.000000  174.200000   67.000000   27.300000
# 75%    379.000000  76011.000000  199.800000   69.000000   31.800000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
minheight=patients[patients['height']==min(patients['height'])]

# %%
minheight
# Out:
#    patient_id assigned_sex given_name  surname               address    city  \
# 4           5         male        Tim  Neudorf  1428 Turkey Pen Lane  Dothan
#
#      state  zip_code        country                          contact  \
# 4  Alabama     36303  United States  334-515-7487TimNeudorf@cuvox.de
#
#    birthdate  weight  height   bmi
# 4 1928-02-18   192.3      27  26.1

# %%
patients=patients.drop(index=4,axis=0)

# %%
patients=patients.reset_index(drop=True)

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             6         male     Rafael        Costa
# ..          ...          ...        ...          ...
# 491         499         male    Mustafa    Lindström
# 492         500         male      Ruman      Bisliev
# 493         501       female      Jinke    de Keizer
# 494         502       female    Chidalu  Onyekaozulu
# 495         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California     92390
# 1    2370 University Hill Road          Armstrong    Illinois     61812
# 2        1493 Poling Farm Road               York    Nebraska     68467
# ...

# %%
minheight1=patients[patients['height']==min(patients['height'])]

# %%
minheight1
# Out:
#      patient_id assigned_sex given_name        surname  \
# 131         133       female      Tekla        Walczak
# 170         172       female    Blagica       Klobučar
# 180         182       female     Yumena       Nakayama
# 229         233       female     Kyouko            Ono
# 262         269       female      Päivi        Mattila
# 283         291       female        Una  Traustadóttir
# 328         336       female      Lixue          Hsueh
# 348         356       female      Chiho           Higa
# 393         401       female      Sonya     Woldendorp
# 416         424       female     Simone   Baumgaertner
# 447         455       female     Bianca        Azevedo
#
#                     address              city          state  zip_code  \
# 131          2421 Coal Road        Lake Ariel   Pennsylvania     18436
# 170     3920 Braxton Street         La Grange       Illinois     60525
# 180  4458 Stark Hollow Road            Gypsum       Colorado     81637
# ...

# %%
#patients['Phone'] = patients['contact'].str.extract(r'([+]?[0-9]+[\s+]?[\(]?[\-]?[0-9]+[\)]?[\s+]?[0-9]+[\s+]?[\-]?[0-9]+)')

# %%
patients['Phone']=patients['contact'].str.extract(r'([+]?[0-9]+?[\s+]?[\(]?[\-]?[0-9]+[\)]?[\s+]?[\-]?[0-9]+[\s+]?[\-]?[0-9]+)')

# %%
patients['email']=patients['contact'].str.extract(r'([a-zA-Z][a-zA-Z\d\.-]+@[a-zA-Z\D-]+\.[a-z]+)')

# %%
patients['Phone']
# Out:
# 0           951-719-9170
# 1      +1 (217) 569-3204
# 2           402-363-6804
# 3      +1 (732) 636-8246
# 4           386-334-5237
#              ...
# 491         207-477-0579
# 492         928-284-4492
# 493         816-223-6007
# 494       1 360 443 2060
# 495         402-848-4923
# Name: Phone, Length: 496, dtype: object

# %%
patients['email']
# Out:
# 0               ZoeWellish@superrito.com
# 1                   PamelaSHill@cuvox.de
# 2                   JaeMDebord@gustr.com
# 3              PhanBaLiem@jourrapide.com
# 4           RafaelCardosoCosta@gustr.com
#                      ...
# 491      MustafaLindstrom@jourrapide.com
# 492               RumanBisliev@gustr.com
# 493            JinkedeKeizer@teleworm.us
# 494    ChidaluOnyekaozulu@jourrapide.com
# 495             PatrickGersten@rhyta.com
# Name: email, Length: 496, dtype: object

# %%
patients.drop(columns='contact',inplace=True)

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             6         male     Rafael        Costa
# ..          ...          ...        ...          ...
# 491         499         male    Mustafa    Lindström
# 492         500         male      Ruman      Bisliev
# 493         501       female      Jinke    de Keizer
# 494         502       female    Chidalu  Onyekaozulu
# 495         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California     92390
# 1    2370 University Hill Road          Armstrong    Illinois     61812
# 2        1493 Poling Farm Road               York    Nebraska     68467
# ...

# %%
patients=patients.rename(columns={'patient_id':"Patient ID","assigned_sex":"Sex","given_name":"First name","surname":"Last Name","address":"Address","city":"City","state":"State","zip_code":"Zip Code","country":"Country","birthdate":"DOB","weight":"Weight","height":"Height","bmi":"BMI","email":"Email"})

# %%
patients.to_csv("clean patients data")

# %%
treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
##hba1c has null value

# %%
treatment
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0             NaN
# 1            0.97
# ...

# %%
treatment_cut
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0       jožka   resanovič  22u - 30u          -         7.56       7.22
# 1   inunnguaq    heilmann  57u - 67u          -         7.85       7.45
# 2       alwin    svensson  36u - 39u          -         7.78       7.34
# 3         thể       lương          -  61u - 64u         7.64       7.22
# 4      amanda     ribeiro  36u - 44u          -         7.85       7.47
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0           0.34
# 1            NaN
# 2            NaN
# 3           0.92
# ...

# %%
##single data in two datset need to append them

# %%
treatment=treatment.append(treatment_cut,ignore_index=True)
# Out:
# C:\Users\Monika Mandal\AppData\Local\Temp\ipykernel_9816\4174985882.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   treatment=treatment.append(treatment_cut,ignore_index=True)

# %%
treatment
# Out:
#     given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika    jindrová  41u - 48u          -         7.63       7.20
# 1       elliot  richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3         skye  gormanston  33u - 36u          -         7.97       7.62
# 4       alissa      montez          -  33u - 29u         7.78       7.46
# ..         ...         ...        ...        ...          ...        ...
# 345     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 346      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 347      bernd   schneider  48u - 56u          -         7.74       7.44
# 348      berta  napolitani          -  42u - 44u         7.68       7.21
# 349     armina       sauvé  36u - 46u          -         7.86       7.40
#
#      hba1c_change
# 0             NaN
# 1            0.97
# 2             NaN
# ...

# %%
"""1.given name and surname column starting letter should be capital
2.aurolin and novodra should be in one column with different starting and ending units
3.hba1c is substraction of hba1c_start -hba1c_end which is wronly calculated
"""
# Out:
# '1.given name and surname column starting letter should be capital\n2.aurolin and novodra should be in one column with different starting and ending units\n3.hba1c is substraction of hba1c_start -hba1c_end which is wronly calculated\n'

# %%
treatment['hba1c_change']=treatment['hba1c_start']-treatment['hba1c_end']

# %%
treatment
# Out:
#     given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika    jindrová  41u - 48u          -         7.63       7.20
# 1       elliot  richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3         skye  gormanston  33u - 36u          -         7.97       7.62
# 4       alissa      montez          -  33u - 29u         7.78       7.46
# ..         ...         ...        ...        ...          ...        ...
# 345     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 346      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 347      bernd   schneider  48u - 56u          -         7.74       7.44
# 348      berta  napolitani          -  42u - 44u         7.68       7.21
# 349     armina       sauvé  36u - 46u          -         7.86       7.40
#
#      hba1c_change
# 0            0.43
# 1            0.47
# 2            0.43
# ...

# %%
treatment['given_name']=treatment['given_name'].str.capitalize()

# %%
treatment
# Out:
#     given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     Veronika    jindrová  41u - 48u          -         7.63       7.20
# 1       Elliot  richardson          -  40u - 45u         7.56       7.09
# 2     Yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3         Skye  gormanston  33u - 36u          -         7.97       7.62
# 4       Alissa      montez          -  33u - 29u         7.78       7.46
# ..         ...         ...        ...        ...          ...        ...
# 345     Rovzan     kishiev  32u - 37u          -         7.75       7.41
# 346      Jakob    jakobsen          -  28u - 26u         7.96       7.51
# 347      Bernd   schneider  48u - 56u          -         7.74       7.44
# 348      Berta  napolitani          -  42u - 44u         7.68       7.21
# 349     Armina       sauvé  36u - 46u          -         7.86       7.40
#
#      hba1c_change
# 0            0.43
# 1            0.47
# 2            0.43
# ...

# %%
treatment['surname']=treatment['surname'].str.capitalize()

# %%
treatment
# Out:
#     given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     Veronika    Jindrová  41u - 48u          -         7.63       7.20
# 1       Elliot  Richardson          -  40u - 45u         7.56       7.09
# 2     Yukitaka    Takenaka          -  39u - 36u         7.68       7.25
# 3         Skye  Gormanston  33u - 36u          -         7.97       7.62
# 4       Alissa      Montez          -  33u - 29u         7.78       7.46
# ..         ...         ...        ...        ...          ...        ...
# 345     Rovzan     Kishiev  32u - 37u          -         7.75       7.41
# 346      Jakob    Jakobsen          -  28u - 26u         7.96       7.51
# 347      Bernd   Schneider  48u - 56u          -         7.74       7.44
# 348      Berta  Napolitani          -  42u - 44u         7.68       7.21
# 349     Armina       Sauvé  36u - 46u          -         7.86       7.40
#
#      hba1c_change
# 0            0.43
# 1            0.47
# 2            0.43
# ...

# %%
adverse
# Out:
#      given_name     surname           adverse_reaction
# 0         berta  napolitani  injection site discomfort
# 1          lena        baer               hypoglycemia
# 2        joseph         day               hypoglycemia
# 3        flavia  fiorentino                      cough
# 4       manouck     wubbels          throat irritation
# 5       jasmine       sykes               hypoglycemia
# 6        louise     johnson               hypoglycemia
# 7       albinca     komavec               hypoglycemia
# 8           noe      aranda               hypoglycemia
# 9         sofia   hermansen  injection site discomfort
# 10        tegan     johnson                   headache
# 11         abel     yonatan                      cough
# 12    abdul-nur         isa               hypoglycemia
# 13         leon      scholz  injection site discomfort
# 14     gabriele     saenger               hypoglycemia
# 15       jia li        teng                     nausea
# ...

# %%
##given_name and surname is small

# %%
adverse['given_name']=adverse['given_name'].str.capitalize()
adverse['surname']=adverse['surname'].str.capitalize()

# %%
len(adverse)
# Out:
# 34

# %%
treatment
# Out:
#     given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     Veronika    Jindrová  41u - 48u          -         7.63       7.20
# 1       Elliot  Richardson          -  40u - 45u         7.56       7.09
# 2     Yukitaka    Takenaka          -  39u - 36u         7.68       7.25
# 3         Skye  Gormanston  33u - 36u          -         7.97       7.62
# 4       Alissa      Montez          -  33u - 29u         7.78       7.46
# ..         ...         ...        ...        ...          ...        ...
# 345     Rovzan     Kishiev  32u - 37u          -         7.75       7.41
# 346      Jakob    Jakobsen          -  28u - 26u         7.96       7.51
# 347      Bernd   Schneider  48u - 56u          -         7.74       7.44
# 348      Berta  Napolitani          -  42u - 44u         7.68       7.21
# 349     Armina       Sauvé  36u - 46u          -         7.86       7.40
#
#      hba1c_change
# 0            0.43
# 1            0.47
# 2            0.43
# ...

# %%
treatment=treatment.merge(adverse,how='left')

# %%
len(treatment[treatment['adverse_reaction'].notnull()])
# Out:
# 35

# %%
treatment
# Out:
#     given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     Veronika    Jindrová  41u - 48u          -         7.63       7.20
# 1       Elliot  Richardson          -  40u - 45u         7.56       7.09
# 2     Yukitaka    Takenaka          -  39u - 36u         7.68       7.25
# 3         Skye  Gormanston  33u - 36u          -         7.97       7.62
# 4       Alissa      Montez          -  33u - 29u         7.78       7.46
# ..         ...         ...        ...        ...          ...        ...
# 345     Rovzan     Kishiev  32u - 37u          -         7.75       7.41
# 346      Jakob    Jakobsen          -  28u - 26u         7.96       7.51
# 347      Bernd   Schneider  48u - 56u          -         7.74       7.44
# 348      Berta  Napolitani          -  42u - 44u         7.68       7.21
# 349     Armina       Sauvé  36u - 46u          -         7.86       7.40
#
#      hba1c_change           adverse_reaction
# 0            0.43                        NaN
# ...

# %%
df=treatment[treatment.duplicated()].index

# %%
df
# Out:
# Int64Index([136], dtype='int64')

# %%
treatment=treatment.drop(df)

# %%
treatment[treatment['given_name']=='Joseph']
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 10      Joseph     Day  29u - 36u       -         7.70       7.19
# 337     Joseph  Tucker  48u - 56u       -         7.67       7.30
#
#      hba1c_change adverse_reaction
# 10           0.51     hypoglycemia
# 337          0.37              NaN

# %%
treatment[treatment.duplicated()]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, auralin, novodra, hba1c_start, hba1c_end, hba1c_change, adverse_reaction]
# Index: []

# %% [markdown]
# treatment

# %%
treatment=treatment.reset_index(drop=True)

# %%
treatment
# Out:
#     given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     Veronika    Jindrová  41u - 48u          -         7.63       7.20
# 1       Elliot  Richardson          -  40u - 45u         7.56       7.09
# 2     Yukitaka    Takenaka          -  39u - 36u         7.68       7.25
# 3         Skye  Gormanston  33u - 36u          -         7.97       7.62
# 4       Alissa      Montez          -  33u - 29u         7.78       7.46
# ..         ...         ...        ...        ...          ...        ...
# 344     Rovzan     Kishiev  32u - 37u          -         7.75       7.41
# 345      Jakob    Jakobsen          -  28u - 26u         7.96       7.51
# 346      Bernd   Schneider  48u - 56u          -         7.74       7.44
# 347      Berta  Napolitani          -  42u - 44u         7.68       7.21
# 348     Armina       Sauvé  36u - 46u          -         7.86       7.40
#
#      hba1c_change           adverse_reaction
# 0            0.43                        NaN
# ...

# %%
treatment=treatment.melt(id_vars=['given_name','surname','hba1c_start','hba1c_end','hba1c_change'],value_vars=['auralin','novodra'],var_name='treatment_tyoe',value_name='doses')

# %%
treatment
# Out:
#     given_name     surname  hba1c_start  hba1c_end  hba1c_change  \
# 0     Veronika    Jindrová         7.63       7.20          0.43
# 1       Elliot  Richardson         7.56       7.09          0.47
# 2     Yukitaka    Takenaka         7.68       7.25          0.43
# 3         Skye  Gormanston         7.97       7.62          0.35
# 4       Alissa      Montez         7.78       7.46          0.32
# ..         ...         ...          ...        ...           ...
# 693     Rovzan     Kishiev         7.75       7.41          0.34
# 694      Jakob    Jakobsen         7.96       7.51          0.45
# 695      Bernd   Schneider         7.74       7.44          0.30
# 696      Berta  Napolitani         7.68       7.21          0.47
# 697     Armina       Sauvé         7.86       7.40          0.46
#
#     treatment_tyoe      doses
# 0          auralin  41u - 48u
# 1          auralin          -
# 2          auralin          -
# 3          auralin  33u - 36u
# ...

# %%
treatment
# Out:
#     given_name     surname  hba1c_start  hba1c_end  hba1c_change  \
# 0     Veronika    Jindrová         7.63       7.20          0.43
# 1       Elliot  Richardson         7.56       7.09          0.47
# 2     Yukitaka    Takenaka         7.68       7.25          0.43
# 3         Skye  Gormanston         7.97       7.62          0.35
# 4       Alissa      Montez         7.78       7.46          0.32
# ..         ...         ...          ...        ...           ...
# 693     Rovzan     Kishiev         7.75       7.41          0.34
# 694      Jakob    Jakobsen         7.96       7.51          0.45
# 695      Bernd   Schneider         7.74       7.44          0.30
# 696      Berta  Napolitani         7.68       7.21          0.47
# 697     Armina       Sauvé         7.86       7.40          0.46
#
#     treatment_tyoe      doses
# 0          auralin  41u - 48u
# 1          auralin          -
# 2          auralin          -
# 3          auralin  33u - 36u
# ...

# %%
df3=treatment[treatment['doses']=='-'].index

# %% [markdown]
# ###

# %%
df3
# Out:
# Int64Index([  1,   2,   4,   5,   8,  11,  13,  17,  18,  19,
#             ...
#             681, 684, 685, 687, 689, 690, 691, 693, 695, 697],
#            dtype='int64', length=349)

# %%
treatment.drop(df3,inplace=True)

# %%
treatment.reset_index(drop=True)
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change  \
# 0       Veronika    Jindrová         7.63       7.20          0.43
# 1           Skye  Gormanston         7.97       7.62          0.35
# 2         Sophia      Haugen         7.65       7.27          0.38
# 3          Eddie      Archer         7.89       7.55          0.34
# 4           Asia     Woźniak         7.76       7.37          0.39
# ..           ...         ...          ...        ...           ...
# 344  Christopher    Woodward         7.51       7.06          0.45
# 345        Maret    Sultygov         7.67       7.30          0.37
# 346        Lixue       Hsueh         9.21       8.80          0.41
# 347        Jakob    Jakobsen         7.96       7.51          0.45
# 348        Berta  Napolitani         7.68       7.21          0.47
#
#     treatment_tyoe      doses
# 0          auralin  41u - 48u
# 1          auralin  33u - 36u
# 2          auralin  37u - 42u
# 3          auralin  31u - 38u
# ...

# %%
treatment[treatment['doses']=='-']
# Out:
# Empty DataFrame
# Columns: [given_name, surname, hba1c_start, hba1c_end, hba1c_change, treatment_tyoe, doses]
# Index: []

# %%
#treatment['initial_dose']=treatment['doses'].str.split('-')

# %%
#treatment=treatment.drop(columns='initial_dose',inplace=True)

# %%
#treatment

# %%
treatment['initial_dose']=[i.split('-')[0]  for i in treatment['doses']]

# %%
treatment['final_dose']=[i.split('-')[1]  for i in treatment['doses']]

# %%
treatment
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change  \
# 0       Veronika    Jindrová         7.63       7.20          0.43
# 3           Skye  Gormanston         7.97       7.62          0.35
# 6         Sophia      Haugen         7.65       7.27          0.38
# 7          Eddie      Archer         7.89       7.55          0.34
# 9           Asia     Woźniak         7.76       7.37          0.39
# ..           ...         ...          ...        ...           ...
# 686  Christopher    Woodward         7.51       7.06          0.45
# 688        Maret    Sultygov         7.67       7.30          0.37
# 692        Lixue       Hsueh         9.21       8.80          0.41
# 694        Jakob    Jakobsen         7.96       7.51          0.45
# 696        Berta  Napolitani         7.68       7.21          0.47
#
#     treatment_tyoe      doses initial_dose final_dose
# 0          auralin  41u - 48u         41u         48u
# ...

# %%
treatment.drop(columns='doses',inplace=True)

# %%
treatment
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change  \
# 0       Veronika    Jindrová         7.63       7.20          0.43
# 3           Skye  Gormanston         7.97       7.62          0.35
# 6         Sophia      Haugen         7.65       7.27          0.38
# 7          Eddie      Archer         7.89       7.55          0.34
# 9           Asia     Woźniak         7.76       7.37          0.39
# ..           ...         ...          ...        ...           ...
# 686  Christopher    Woodward         7.51       7.06          0.45
# 688        Maret    Sultygov         7.67       7.30          0.37
# 692        Lixue       Hsueh         9.21       8.80          0.41
# 694        Jakob    Jakobsen         7.96       7.51          0.45
# 696        Berta  Napolitani         7.68       7.21          0.47
#
#     treatment_tyoe initial_dose final_dose
# 0          auralin         41u         48u
# 3          auralin         33u         36u
# ...

# %%
treatment
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change  \
# 0       Veronika    Jindrová         7.63       7.20          0.43
# 3           Skye  Gormanston         7.97       7.62          0.35
# 6         Sophia      Haugen         7.65       7.27          0.38
# 7          Eddie      Archer         7.89       7.55          0.34
# 9           Asia     Woźniak         7.76       7.37          0.39
# ..           ...         ...          ...        ...           ...
# 686  Christopher    Woodward         7.51       7.06          0.45
# 688        Maret    Sultygov         7.67       7.30          0.37
# 692        Lixue       Hsueh         9.21       8.80          0.41
# 694        Jakob    Jakobsen         7.96       7.51          0.45
# 696        Berta  Napolitani         7.68       7.21          0.47
#
#     treatment_tyoe initial_dose final_dose
# 0          auralin         41u         48u
# 3          auralin         33u         36u
# ...

# %%
treatment['initial_dose']=treatment['initial_dose'].str.replace('u','')

# %%
treatment['final_dose']=treatment['final_dose'].str.replace('u','')

# %%
treatment
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change  \
# 0       Veronika    Jindrová         7.63       7.20          0.43
# 3           Skye  Gormanston         7.97       7.62          0.35
# 6         Sophia      Haugen         7.65       7.27          0.38
# 7          Eddie      Archer         7.89       7.55          0.34
# 9           Asia     Woźniak         7.76       7.37          0.39
# ..           ...         ...          ...        ...           ...
# 686  Christopher    Woodward         7.51       7.06          0.45
# 688        Maret    Sultygov         7.67       7.30          0.37
# 692        Lixue       Hsueh         9.21       8.80          0.41
# 694        Jakob    Jakobsen         7.96       7.51          0.45
# 696        Berta  Napolitani         7.68       7.21          0.47
#
#     treatment_tyoe initial_dose final_dose
# 0          auralin          41          48
# 3          auralin          33          36
# ...

# %%
treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349 entries, 0 to 696
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   given_name      349 non-null    object
#  1   surname         349 non-null    object
#  2   hba1c_start     349 non-null    float64
#  3   hba1c_end       349 non-null    float64
#  4   hba1c_change    349 non-null    float64
#  5   treatment_tyoe  349 non-null    object
#  6   initial_dose    349 non-null    object
#  7   final_dose      349 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 24.5+ KB

# %%
treatment['initial_dose']=treatment['initial_dose'].astype('int')

# %%
treatment['final_dose']=treatment['final_dose'].astype('int')

# %%
treatment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349 entries, 0 to 696
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   given_name      349 non-null    object
#  1   surname         349 non-null    object
#  2   hba1c_start     349 non-null    float64
#  3   hba1c_end       349 non-null    float64
#  4   hba1c_change    349 non-null    float64
#  5   treatment_tyoe  349 non-null    object
#  6   initial_dose    349 non-null    int32
#  7   final_dose      349 non-null    int32
# dtypes: float64(3), int32(2), object(3)
# memory usage: 21.8+ KB

# %%
treatment.rename(columns={'given_name':'First Name','surname':'Last Name','hba1c_start':'hba1c level start','hba1c_end':'hba1c level end','hba1c_change':'hba1c Change','treatment_tyoe':'Treatment type','initial_dose':'Initial Dose','final_dose':'Final Dose'},inplace=True)

# %%
treatment
# Out:
#       First Name   Last Name  hba1c level start  hba1c level end  \
# 0       Veronika    Jindrová               7.63             7.20
# 3           Skye  Gormanston               7.97             7.62
# 6         Sophia      Haugen               7.65             7.27
# 7          Eddie      Archer               7.89             7.55
# 9           Asia     Woźniak               7.76             7.37
# ..           ...         ...                ...              ...
# 686  Christopher    Woodward               7.51             7.06
# 688        Maret    Sultygov               7.67             7.30
# 692        Lixue       Hsueh               9.21             8.80
# 694        Jakob    Jakobsen               7.96             7.51
# 696        Berta  Napolitani               7.68             7.21
#
#      hba1c Change Treatment type  Initial Dose  Final Dose
# 0            0.43        auralin            41          48
# 3            0.35        auralin            33          36
# ...

# %%
treatment=treatment.reset_index(drop=True)

# %%
treatment
# Out:
#       First Name   Last Name  hba1c level start  hba1c level end  \
# 0       Veronika    Jindrová               7.63             7.20
# 1           Skye  Gormanston               7.97             7.62
# 2         Sophia      Haugen               7.65             7.27
# 3          Eddie      Archer               7.89             7.55
# 4           Asia     Woźniak               7.76             7.37
# ..           ...         ...                ...              ...
# 344  Christopher    Woodward               7.51             7.06
# 345        Maret    Sultygov               7.67             7.30
# 346        Lixue       Hsueh               9.21             8.80
# 347        Jakob    Jakobsen               7.96             7.51
# 348        Berta  Napolitani               7.68             7.21
#
#      hba1c Change Treatment type  Initial Dose  Final Dose
# 0            0.43        auralin            41          48
# 1            0.35        auralin            33          36
# ...

# %%
treatment.to_csv("treatment_clean")
